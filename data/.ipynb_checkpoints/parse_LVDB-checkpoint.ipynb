# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table

# %%
# cat = Table.read('./Pace_dwarf_all.csv')
cat = Table.read('./LVDB_comb_all.csv')

# %%
cat
# Out:
# <Table length=1706>
#       key                ra         ...  table   confirmed_star_cluster
#      str31            float64       ...  str25           int64
# ---------------- ------------------ ... -------- ----------------------
#         antlia_2           143.8079 ... dwarf_mw                     --
#       aquarius_2           338.4813 ... dwarf_mw                     --
#       aquarius_3            357.218 ... dwarf_mw                     --
#         bootes_1             210.02 ... dwarf_mw                     --
#         bootes_2           209.5141 ... dwarf_mw                     --
#         bootes_3              209.3 ... dwarf_mw                     --
#         bootes_4            233.689 ... dwarf_mw                     --
#         bootes_5            213.909 ... dwarf_mw                     --
# canes_venatici_1           202.0091 ... dwarf_mw                     --
#              ...                ... ...      ...                    ...
# ...
